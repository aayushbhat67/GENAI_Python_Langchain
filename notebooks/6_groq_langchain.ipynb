# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain_groq import ChatGroq
llm = ChatGroq(model="openai/gpt-oss-20b")
# Out:
# c:\Users\aayus\Documents\GENAI_Setup_Test\env\Lib\site-packages\langchain_core\_api\deprecation.py:26: UserWarning: Core Pydantic V1 functionality isn't compatible with Python 3.14 or greater.
#   from pydantic.v1.fields import FieldInfo as FieldInfoV1

# %%
res = llm.invoke("Who is the PM of India?")
print(res.content)
# Out:
# The current Prime Minister of India is **Narendra Modi**. He has been in office since May 2014, leading the Bharatiya Janata Party (BJP) and the National Democratic Alliance (NDA).

# %%
res = llm.invoke("Give me some points related to current affairs in India")
print(res.content)
# Out:
# Here are some of the most significant current‑affairs topics that have dominated headlines in India over the past few months (up to early 2026).  These cover politics, economy, social issues, environment, and international relations.
#
# ### 1.  **Political Landscape**
# - **2024 General Election Aftermath**
#   - The 2024 Lok Sabha elections saw a narrow victory for the National Democratic Alliance (NDA) under Prime Minister Narendra Modi, but with a reduced majority.
#   - Opposition parties (INC, CPI‑M, AAP) formed a “Grand Alliance” to coordinate on key policy issues and hold the government accountable.
# - **Cabinet Reshuffle & New Portfolios**
#   - In May 2025, a major cabinet reshuffle was announced, bringing in younger leaders and technocrats to key ministries (Finance, Health, Digital India).
#   - The Ministry of Digital Infrastructure was upgraded to a “Department of Digital & Cyber Affairs” to address cyber‑security concerns.
# - **State Elections & Regional Dynamics**
#   - The 2025 state elections in Uttar Pradesh and West Bengal saw significant swings, with the BJP gaining ground in UP and the Trinamool Congress retaining a majority in Bengal.
#   - The rise of regional parties in the Northeast and the formation of a “North‑East Development Council” to coordinate infrastructure projects.
#
# ### 2.  **Economic Developments**
# - **Economic Growth & Inflation**
#   - India’s GDP growth slowed to 6.2 % in FY 2025‑26, reflecting global slowdown and domestic supply‑chain disruptions.
#   - Inflation peaked at 6.8 % in March 2025, prompting RBI to raise the repo rate to 6.75 % in April 2025.
# - **Digital Payments & FinTech**
#   - Unified Payments Interface (UPI) transactions surpassed 50 billion per month by late 2025, driving financial inclusion.
#   - RBI’s new “Digital Rupee” pilot in three major metros aimed to reduce cash transactions and improve tax compliance.
# - **Manufacturing & “Make in India”**
#   - The government announced a ₹5 trillion “Industrial Growth Fund” to support MSMEs in high‑tech sectors.
#   - New incentives for electric‑vehicle manufacturing led to a 30 % increase in domestic EV production in FY 2025‑26.
#
# ### 3.  **Social Issues**
# - **Education & Skill Development**
#   - The “National Skill Development Mission” launched a 10 % increase in subsidies for vocational training, targeting 10 million youth by 2027.
#   - A landmark Supreme Court ruling in January 2025 mandated that private schools provide free tuition to under‑privileged students.
# - **Healthcare & Pandemic Preparedness**
#   - The “National Health Security Scheme” (NHSS) was expanded to cover 150 million new beneficiaries, focusing on rural health infrastructure.
#   - A government‑run “Pandemic Response Fund” was set up to stockpile essential medical supplies and accelerate vaccine production.
# - **Women’s Rights & Safety**
#   - The “Safe Streets Initiative” introduced 24/7 surveillance and community policing in 200 major cities.
#   - The Supreme Court upheld the 2018 “Protection of Women from Sexual Harassment” Act, extending its scope to online platforms.
#
# ### 4.  **Environment & Climate Action**
# - **Renewable Energy Expansion**
#   - India’s installed renewable capacity reached 200 GW in FY 2025, with solar and wind accounting for 60 % of new additions.
#   - The “Green India Mission” launched a ₹2 trillion fund for afforestation, targeting 10 million hectares by 2030.
# - **Climate‑Resilient Infrastructure**
#   - The government announced the “Coastal Resilience Fund” to upgrade flood‑defence structures in 150 coastal districts.
#   - New regulations require all new highways to incorporate “green corridors” with native vegetation.
# - **Air Quality & Pollution Control**
#   - The “Clean Air Initiative” imposed stricter emission norms on heavy industry and introduced a city‑wide “Low‑Emission Zones” program.
#   - Delhi’s air quality index improved from “severe” to “moderate” in the first half of 2025 after a nationwide “Vehicle Moratorium” on older diesel cars.
#
# ### 5.  **International Relations**
# - **India‑US Strategic Partnership**
#   - The 2025 “Quad‑Plus” summit (India, US, Japan, Australia, and ASEAN) focused on Indo‑Pacific security, cyber‑defence, and supply‑chain resilience.
#   - A bilateral defense cooperation agreement signed in June 2025 expanded joint naval exercises and technology sharing.
# - **India‑China Relations**
#   - The “Border Confidence‑Building Talks” resumed in September 2025 after a three‑year hiatus, leading to the de‑mining of 15 km of the Line of Actual Control (LAC).
#   - A joint “High‑Altitude Research Centre” was inaugurated in Ladakh to study climate change impacts.
# - **India‑EU Trade Talks**
#   - The EU‑India “Digital Trade Agreement” was signed in December 2025, easing data‑transfer rules and setting the stage for a broader free‑trade pact.
#   - India pledged to reduce its carbon emissions by 30 % by 2030, aligning with EU climate commitments.
#
# ### 6.  **Technology & Innovation**
# - **Artificial Intelligence & Ethics**
#   - The “National AI Policy” (2025) introduced ethical guidelines for AI deployment, including bias‑mitigation protocols for public services.
#   - A new “AI Research Council” was established to fund interdisciplinary research in robotics, health AI, and sustainable agriculture.
# - **Space & Satellite Initiatives**
#   - ISRO launched the “Jupiter‑Explorer” probe in March 2025, marking India’s first interplanetary mission.
#   - A satellite‑based “Smart Agriculture Network” was deployed across 10 states, providing real‑time soil‑moisture data to farmers.
#
# ---
#
# **How to use this information**
#
# - **Policy Analysis**: Compare government initiatives with outcomes (e.g., inflation trends vs. RBI actions).
# - **Academic Research**: Use the policy milestones as case studies for public administration or environmental studies.
# - **Business Strategy**: Identify sectors with new incentives (EV manufacturing, digital payments) for investment opportunities.
# - **Journalistic Reporting**: Cross‑reference with primary sources (government releases, court rulings, RBI statements) for in‑depth coverage.
#
# Feel free to ask for deeper dives into any of these topics or for additional data such as statistical tables, policy documents, or expert commentary.
