# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %% [markdown]
# #### TEXT DOCUMENT LOADER

# %%
from langchain_community.document_loaders import TextLoader
loader=TextLoader("../Data/My Resume.txt")
text = loader.load();
text
len(text)

oneDoc = text[0]
print(oneDoc.page_content)
# Out:
# Aayush Bhat
#
#
# aayushbhat67@gmail.com
# 8899338812
# India
# https://www.linkedin.com/in/aayush-bhat-91a83a216
#
#
#
# ------------------------
# Senior Analyst - Capgemini Technology Services
#
#
# ------------------------
# <b><u>Proactive .NET Full Stack Developer</u></b> with practical experience in developing robust and scalable web solutions using <b><u>ASP.NET MVC, .NET Web API, JavaScript, jQuery, HTML, CSS,</u></b><u> and <b>SQL Server</b></u>. Adaptive at implementing efficient features and improving user engagement through up-to-date frontend and backend technologies.
#
#
# Work Experience
# ------------------------
# Senior Analyst
# Capgemini Technology Services
# 07/2025 - Present
# Navi Mumbai, India
# Achievements/Tasks
#
#
#
# Analyst / Software Engineer
# Capgemini Technology Services
# 08/2023 - 06/2025
# Navi Mumbai , India
# Achievements/Tasks
# ...

# %% [markdown]
# #### PDF DOCUMENT LOADER

# %%
from langchain_community.document_loaders import PyPDFLoader 
loader = PyPDFLoader("../Data/0121YG008021121_190858c.pdf")
text = loader.load()
text
len(text)

oneDoc = text[0]
print(oneDoc.page_content)
# Out:
# DIAGNOSTIC REPORT
# PLOT NO.1, LANE NO. 1,  SITUATED AT HAZURI
# BAGH ROAD, TALAB TILLO,
# PATIENT NAME :  AYUSH BHAT
# PATIENT ID       : AYUSM217552130
# ACCESSION NO : 0121YG008021 AGE/SEX    :22 Years Male
# ABHA NO          :
# DRAWN      :24/07/2025 12:21:00
# RECEIVED  :24/07/2025 13:02:03
# REPORTED  :24/07/2025 17:25:30
# REF. DOCTOR :  SELF
# CLIENT PATIENT ID:
# CODE/NAME & ADDRESS  : C000079918
# SAI MULTISPECIALITY
# JAMMU 180002
# 7006048100 9419191754
# Final Results Biological Reference IntervalTest Report Status Units
# HAEMATOLOGY - CBC
# COMPLETE CARE SCREEN
# BLOOD COUNTS,EDTA WHOLE BLOOD
# HEMOGLOBIN (HB) 13.2 13.0 - 17.0 g/dL
# RED BLOOD CELL (RBC) COUNT 4.48  Low 4.5 - 5.5 mil/µL
# WHITE BLOOD CELL (WBC) COUNT 4.55 4.0 - 10.0 thou/µL
# PLATELET COUNT 219 150 - 410 thou/µL
# RBC AND PLATELET INDICES
# HEMATOCRIT (PCV) 39.7  Low 40 - 50 %
# MEAN CORPUSCULAR VOLUME (MCV) 88.8 83 - 101 fL
# MEAN CORPUSCULAR HEMOGLOBIN (MCH) 29.6 27.0 - 32.0 pg
# ...

# %% [markdown]
# #### CSV DOCUMENT LOADER

# %%
from langchain_community.document_loaders import CSVLoader
loader = CSVLoader("../Data/Expenses_Jan_2026(FAQs).csv")
doc = loader.load()
doc
len(doc)

onDoc = doc[0]
print(onDoc.page_content)
# Out:
# CORE BUDGET RULES: QUESTIONS
# : ANSWERS

# %% [markdown]
# #### WEB PAGE LOADER

# %%
from langchain_community.document_loaders import WebBaseLoader
loader = WebBaseLoader(web_path="https://techsimplus.com")
docs = loader.load()
docs[0].page_content
# Out:
# "TechSimPlus : Transforming Careers through Cutting-Edge Tech TrainingInternshipInstitute SolutionsEventsAbout UsCertificateConnect UsLoginHomeEventsAbout UsInstitute SolutionConnect UsLoginCopyright 2026 © TechSimPlus - The Symbol of Expertise.Designed by\xa0 Prateek MishraCode. Build. Get Hired.Explore our courses12k+Trained Students200+Institute Trainings500+Projects11 LPA+Avarage CTCWatch intro videoOur students got a placementThese are students who joined Techsimplus to expand their careers and were placed on high-tech companies.Anuprash GuptaArun PariharAshutosh MajhiAkshat JainAjay Kumar MandalAkash HarioudhAnuj PandeyAman ShahAnandita KumariAnkit LambaAnshu KumariAnuprash GuptaArun PariharAshutosh MajhiAkshat JainTarun DangiTanay SisodiyaBhagyashree GohiyaBharat TiwariManish Singh Naresh Choudhary Nidhi Khandelwal Nipun Gupta Pratiksha DubeyRaghav KabraVidhi bhardwajPrince KhatriTarun DangiTanay SisodiyaBhagyashree GohiyaBharat TiwariSee what our Student's SayDiscover what ou
# ...

# %% [markdown]
# #### WIKIPEDIA LOADER

# %%
from langchain_community.document_loaders import WikipediaLoader
loader = WikipediaLoader(query="GEN AI", load_max_docs=2)
docs =  loader.load()

# %%
docs
# Out:
# [Document(metadata={'title': 'Generative AI', 'summary': "Generative artificial intelligence, also known as generative AI or GenAI, is a subfield of artificial intelligence that uses generative models to generate text, images, videos, audio, software code or other forms of data. These models learn the underlying patterns and structures of their training data, and use them to generate new data in response to input, which often takes the form of natural language prompts.\nThe prevalence of generative AI tools has increased significantly since the AI boom in the 2020s. This boom was made possible by improvements in deep neural networks, particularly large language models (LLMs), which are based on the transformer architecture. Generative AI applications include chatbots such as ChatGPT, Claude, Copilot, DeepSeek, Google Gemini and Grok; text-to-image models such as Stable Diffusion, Flux, Midjourney, and DALL-E; and text-to-video models such as Veo, LTX and Sora.\nCompanies in a variety
# ...

# %%
len(docs)
# Out:
# 2

# %%
docs[0].page_content
# Out:
# 'Generative artificial intelligence, also known as generative AI or GenAI, is a subfield of artificial intelligence that uses generative models to generate text, images, videos, audio, software code or other forms of data. These models learn the underlying patterns and structures of their training data, and use them to generate new data in response to input, which often takes the form of natural language prompts.\nThe prevalence of generative AI tools has increased significantly since the AI boom in the 2020s. This boom was made possible by improvements in deep neural networks, particularly large language models (LLMs), which are based on the transformer architecture. Generative AI applications include chatbots such as ChatGPT, Claude, Copilot, DeepSeek, Google Gemini and Grok; text-to-image models such as Stable Diffusion, Flux, Midjourney, and DALL-E; and text-to-video models such as Veo, LTX and Sora.\nCompanies in a variety of sectors have used generative AI, including those in s
# ...
