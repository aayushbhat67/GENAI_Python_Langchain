# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
documents = [
    "My name is Aayush Bhat",
    "I am from Jammu",
    "I am learning GenAI",
    "India won the cricket world cup in 2011"
]

# %%
from langchain_openai import OpenAIEmbeddings
# Out:
# c:\Users\aayus\Documents\GENAI_Setup_Test\env\Lib\site-packages\langchain_core\_api\deprecation.py:25: UserWarning: Core Pydantic V1 functionality isn't compatible with Python 3.14 or greater.
#   from pydantic.v1.fields import FieldInfo as FieldInfoV1

# %%
embeddings = OpenAIEmbeddings(model="text-embedding-3-small")

# %%
vector = embeddings.embed_documents(documents)

# %%
len(vector[0])
# Out:
# 1536

# %% [markdown]
# #### STORE EMBEDDINGS IN VECTOR STORES

# %%
from langchain_chroma import Chroma

# %%
vector_store = Chroma.from_texts(
    texts=documents,
    embedding=embeddings,
    persist_directory="./vector_db"
)

# %%
query = "Date"
result = vector_store.similarity_search(query=query)
result
# Out:
# [Document(id='121b3d68-44c3-4e2e-a46a-44f6dfca6e6b', metadata={}, page_content='I am from Jammu'),
#  Document(id='3ae42c5a-e6b8-4b53-b3db-a7b1af445b97', metadata={}, page_content='My name is Aayush Bhat'),
#  Document(id='de232799-fc94-4e93-9c27-0d5b37a055bc', metadata={}, page_content='I am learning GenAI'),
#  Document(id='8caf06e4-3f63-474b-afe1-a388374a20c2', metadata={}, page_content='India won the cricket world cup in 2011')]
