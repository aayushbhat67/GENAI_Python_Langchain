# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain_openai import ChatOpenAI
llm = ChatOpenAI(model="gpt-4", streaming=True)
# Out:
# c:\Users\aayus\Documents\GENAI_Setup_Test\env\Lib\site-packages\langchain_core\_api\deprecation.py:26: UserWarning: Core Pydantic V1 functionality isn't compatible with Python 3.14 or greater.
#   from pydantic.v1.fields import FieldInfo as FieldInfoV1

# %%
question = "Can you tell me about GENAi"

# %%
response = llm.stream(question)
for chunk in response:
    print(chunk.content,end="")
# Out:
# GENAi is an artificial intelligence model developed by OpenAI. It is the sibling model of ChatGPT, another OpenAI model. GENAi has been trained on diverse sources of information from the internet, although it doesn't know specifics about which sources it has learned from. It is designed to generate accurate and helpful responses for a wide array of topics. However, like any AI, it possesses limitations, such as potentially providing incorrect or irrelevant responses, and it doesn't possess beliefs or desires, despite its ability to simulate conversation. It is also designed with safeguards in place to prevent it from engaging in discussions about certain topics that violate OpenAI's use-case policy.

# %%
from langchain_groq import ChatGroq
groqllm = ChatGroq(model="openai/gpt-oss-20b",streaming=True)

# %%
question = "Can you explain me GenAI?"
response = groqllm.stream(question)
for chunk in response:
    print(chunk.content, end="")
# Out:
# ## What is GenAI?
#
# **GenAI** = *Generative Artificial Intelligence*.
# It’s a class of AI systems that **create** new content—text, images, audio, video, code, and more—rather than just recognizing or classifying existing data.
#
# ---
#
# ### 1. The Core Idea
#
# | Traditional AI | GenAI |
# |-----------------|-------|
# | “Given input, produce a label or decision.” | “Given a prompt, produce brand‑new content.” |
# | Example: spam filter, image classifier | Example: ChatGPT (text), DALL‑E (images), Midjourney (art), Stable Diffusion (image generation) |
#
# ---
#
# ### 2. How It Works (High‑Level)
#
# 1. **Training on Huge Datasets**
#    * Collect millions–billions of examples (books, articles, code, images, etc.).
#    * The model learns statistical patterns—what words follow each other, how shapes look, how sound waves combine.
#
# 2. **Neural Architecture: Transformers**
#    * **Self‑attention** lets the model weigh every part of the input relative to every other part.
#    * This gives it context awareness (e.g., “the bank of the river” vs. “the bank of money”).
#
# 3. **Learning to Predict**
#    * During training, the model is asked: “What comes next?”
#    * It adjusts internal weights to minimize prediction error.
#    * Over time, it captures grammar, facts, styles, and even creative patterns.
#
# 4. **Generation (Inference)**
#    * You give a *prompt* (e.g., “Write a short poem about rain”).
#    * The model samples from its learned distribution to produce a coherent output.
#    * Techniques: greedy decoding, beam search, temperature scaling, nucleus sampling, etc.
#
# 5. **Fine‑Tuning / Prompt Engineering**
#    * After the base model, you can adapt it to a specific domain (medical, legal, code).
#    * Or you can craft prompts to steer the style, tone, or content.
#
# ---
#
# ### 3. Types of GenAI
#
# | Domain | Typical Models | Key Use Cases |
# |--------|----------------|---------------|
# | **Text** | GPT‑4, LLaMA, Claude | Chatbots, summarization, translation, creative writing |
# | **Images** | Diffusion models (Stable Diffusion, Imagen), GANs | Art creation, photo editing, design mockups |
# | **Audio** | WaveNet, Jukebox, Whisper | Music generation, speech synthesis, voice cloning |
# | **Video** | Video diffusion, VQ‑VAE, 3D‑GANs | Short clips, animation, video upscaling |
# | **Code** | Codex, AlphaCode | Autocomplete, bug fixing, algorithm generation |
#
# ---
#
# ### 4. Why It Matters
#
# | Benefit | Example |
# |---------|---------|
# | **Speed & Scale** | Generate a thousand product descriptions in minutes. |
# | **Personalization** | Tailor marketing copy to each customer’s style. |
# | **Creativity** | Artists get new inspiration or complete drafts. |
# | **Accessibility** | Translate complex text into plain language instantly. |
# | **Automation** | Draft legal documents, code snippets, or news articles. |
#
# ---
#
# ### 5. Challenges & Ethical Considerations
#
# | Issue | What It Means |
# |-------|---------------|
# | **Bias & Fairness** | Models reflect biases in training data (gender, race, politics). |
# | **Misinformation** | Generated content can be convincing but false. |
# | **Copyright** | Training on copyrighted text/images may infringe. |
# | **Safety** | Models can produce harmful or disallowed content. |
# | **Energy & Cost** | Training large models consumes massive compute and electricity. |
# | **Explainability** | It’s hard to trace *why* a model made a particular decision. |
#
# ---
#
# ### 6. A Simple Analogy
#
# > Imagine a chef who has tasted millions of dishes.
# > When you ask the chef to “cook a new recipe for a spicy vegan dessert,” they can mix ingredients in novel ways that still taste good—because they’ve learned patterns from all those previous dishes.
# > GenAI is that chef, but for text, images, audio, etc.
#
# ---
#
# ### 7. Quick Takeaway
#
# - **GenAI** = AI that *creates* new content.
# - Powered mainly by **transformers** and **diffusion models**.
# - Trained on huge datasets, learns to predict the next element, then uses that knowledge to generate.
# - Widely used in chatbots, art tools, code helpers, and more.
# - Offers huge productivity gains but requires careful handling of bias, safety, and ethics.
#
# ---
#
# **Want to dive deeper?**
# - Explore the architecture of transformers (self‑attention, positional encoding).
# - Read about diffusion models and how they iteratively “denoise” random noise into an image.
# - Look into fine‑tuning techniques like LoRA, QLoRA, or prompt engineering best practices.
