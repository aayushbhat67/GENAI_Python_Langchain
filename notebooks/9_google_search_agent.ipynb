# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain_community.utilities import GoogleSerperAPIWrapper
from langchain_groq import ChatGroq
from langchain.agents import create_agent 
from langgraph.checkpoint.memory import MemorySaver

# %%
llm = ChatGroq(model="openai/gpt-oss-20b")
search = GoogleSerperAPIWrapper()

# %%
search.run("Address of GurSimran Khamba")
# Out:
# "189K followers · 713 following · 926 posts · @gursimrankhamba: “Director Light@27 Podcasting @thatsjusthowwetalk Gameshowing @nationwantstoguess Queries: ... Gursimran Khamba, based in Mumbai, MH, IN, is currently a Founder at Light@27 Media. Gursimran Khamba brings experience from previous roles at All India ... Khamba. 218969 likes · 223 talking about this. Founder Light@27! Co-founder AIB. Comedian. Writer, Creator and Showrunner of the Amazon Original -... He was a me-too casualty. The other 3 apologised for ignoring his behaviour, pretty much throwing him under the bus. Contact Us. Contact Us. Regd Office. Bengaluru. 62/1, New.7, 1st Cross, 2nd Main Rd, Ganganagar, Bengaluru, Karnataka. 560032. Gurgaon. Infrapro Spaces ... Gursimran Khamba in Amsterdam! Khamba is a stand up comic, writer, director, producer and various other titles that require constantly chasing after ... Gursimran Khamba presents a brand-new comedy quiz show The Nation Wants To Guess! The first episode features one of India's funniest panels ... Gursimran Khamba was born in Delhi, India. He is known for Chintu Ka Birthday (2020), Chalo Koi Baat Nahi (2021) and Gormint (2020). I) Gursimranjeet Khamba, the other co-founder of AIB along with Tanmay Bhat, was one of the anti-reservation group representatives who met the then President- ... SHOW ANNOUNCEMENT: The Comedy Cornershop proudly present Gursimran Khamba live at The Glee Club Glasgow on Sat 26th Oct 2024! He's a stand up comic, writer, ..."

# %%
agent = create_agent(
    model=llm,
    tools=[search.run],
    system_prompt="You are an agent that can search any question on Google.",
    checkpointer=MemorySaver()
)

# %%
question = "Total Runs ?"

# %%
response = agent.invoke(
    {"messages":[{"role":"user","content":question}]},
    {"configurable":{"thread_id":"1"}},
)

# %%
print(response["messages"][-1].content)
# Out:
# I’m not sure which “total runs” you’re looking for. Could you let me know a bit more? For example:
#
# - Are you asking about baseball (e.g., total runs scored in a season, by a team, or by a player)?
# - Or cricket (total runs in a series, tournament, or by a player)?
# - Or something else entirely?
#
# Once I know the context, I can give you the exact number.
